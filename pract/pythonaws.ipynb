# %%
print('Hola mundo2')
# Out:
# Hola mundo2

# %%
print(4+5)
# Out:
# 9

# %%
print(type ("hola"))
print(type (288))
print(type (10.5))
print(type (True))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
nombre="Edwin"
edad = 44
notas= 6.9
casado= False

# %%
print (edad)
# Out:
# 44

# %%
nombre="Titanic"
year=2000
Visto=False
print('la pelicula {} del año {} fue vista {}'.format(nombre,year,Visto))
# Out:
# la pelicula Titanic del año 2000 fue vista False

# %%
movie=[
    "The Shawshank Redemption",
    "The Dark Knight",
    "Inception",
    "Pulp Fiction",
    "The Matrix",
    "Interstellar",
    "Parasite",
    "Gladiator",
    "Titanic",
    "The Lord of the Rings: The Fellowship of the Ring"
]
year=[
    1994,
    2008,
    2010,
    1994,
    1999,
    2014,
    2019,
    2000,
    1997,
    2001
]
vista=[
    True,
    False,
    True,
    False,
    True,
    False,
    True,
    False,
    True,
    True
]

# %%
def movrev(movie,year,vista):
    for movie,year,vista in zip(movie,year,vista):
        print(f"la pelicula {movie} del año {year} fue vista {vista}")

# %%
movrev(movie,year,vista)
# Out:
# la pelicula The Shawshank Redemption del año 1994 fue vista True
# la pelicula The Dark Knight del año 2008 fue vista False
# la pelicula Inception del año 2010 fue vista True
# la pelicula Pulp Fiction del año 1994 fue vista False
# la pelicula The Matrix del año 1999 fue vista True
# la pelicula Interstellar del año 2014 fue vista False
# la pelicula Parasite del año 2019 fue vista True
# la pelicula Gladiator del año 2000 fue vista False
# la pelicula Titanic del año 1997 fue vista True
# la pelicula The Lord of the Rings: The Fellowship of the Ring del año 2001 fue vista True

# %%
import pandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 import pandas
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas
